# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/sabah0312/ml-datasets/refs/heads/main/regression_toy_data'
df = pd.read_csv(url,   delim_whitespace=True)

df
# Out:
# /tmp/ipython-input-4054934967.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(url,   delim_whitespace=True)
#         X       y
# 0 -0.5868 -0.0629
# 1  2.3774  5.5750
# 2 -1.2226 -1.2777
# 3  1.7578  4.6421
# 4 -0.8263 -0.6274
# 5  0.0053  1.2752
# 6 -1.0513 -1.1674
# 7 -1.4091 -1.6157
# 8  0.8233  2.6576
# 9  0.6964  2.3758

# %%
import torch

X = torch.tensor(df['X'].values, dtype= torch.float32)
y = torch.tensor(df['y'].values, dtype= torch.float32)

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
class Perceptron:
  def __init__(self, num_features, learning_rate = 0.01):
    self.w = torch.randn(num_features, 1, requires_grad=True)
    self.bias = torch.randn(1, requires_grad=True)
    self.learning_rate = learning_rate

  def forward(self, x):
    return  x @ self.w + self.bias

  def update(self, x, y_true):
    prediction = self.forward(x)
    error = (y_true - prediction)**2
    error = error.mean()

    error.backward()
    # print(f"weight grads: {self.w}")
    # print(f"bias grads: {self.bias}")
    with torch.no_grad():
      self.bias -= self.learning_rate * self.bias.grad
      self.w -= self.learning_rate * self.w.grad

    self.w.grad.zero_()
    self.bias.grad.zero_()
    return error

# %%
PPn = Perceptron(1)
PPn.update(X[1], y[1])
# Out:
# weight grads: tensor([[-1.5646]], requires_grad=True)
# bias grads: tensor([-0.0957], requires_grad=True)
# tensor(88.1784, grad_fn=<MeanBackward0>)

# %%
PPn = Perceptron(1)

print(f"initial weights: {PPn.w}")
print(f"initial bias : {PPn.bias}")
epoch_no = 150
for epoch in range(epoch_no):
  error_total = 0
  for i in range(len(X)):
    x = X[i]
    error = PPn.update(x, y[i])
    error_total += abs(error)
  if epoch%10 == 0:
    print(f"epoch: {epoch}/ {epoch_no}, error: {error_total}")
print(f" weights: {PPn.w}")
print(f" bias : {PPn.bias}")
# Out:
# initial weights: tensor([[1.1868]], requires_grad=True)
# initial bias : tensor([1.0843], requires_grad=True)
# epoch: 0/ 150, error: 7.392400741577148
# epoch: 10/ 150, error: 0.14331109821796417
# epoch: 20/ 150, error: 0.1338648498058319
# epoch: 30/ 150, error: 0.1339157372713089
# epoch: 40/ 150, error: 0.133917436003685
# epoch: 50/ 150, error: 0.1339174509048462
# epoch: 60/ 150, error: 0.13391733169555664
# epoch: 70/ 150, error: 0.1339174062013626
# epoch: 80/ 150, error: 0.1339174062013626
# epoch: 90/ 150, error: 0.1339174062013626
# epoch: 100/ 150, error: 0.1339174062013626
# epoch: 110/ 150, error: 0.1339174062013626
# epoch: 120/ 150, error: 0.1339174062013626
# epoch: 130/ 150, error: 0.1339174062013626
# epoch: 140/ 150, error: 0.1339174062013626
#  weights: tensor([[1.9536]], requires_grad=True)
#  bias : tensor([1.0675], requires_grad=True)
